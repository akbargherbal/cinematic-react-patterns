# %%
#

# %%
import pandas as pd
import regex as re
import os
from pathlib import Path

# %%
pwd
# Out:
# '/mnt/c/Users/DELL/AppData/Local/Programs/Microsoft VS Code'

# %%
list_json = []
for root, dirs, files in os.walk('../../src/modules/'):
    for file in files:
        if file.endswith('.json'):
            list_json.append(os.path.join(root, file).replace(os.sep, '/'))

# %%
list_json
